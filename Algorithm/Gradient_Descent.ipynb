# %%
## 경사 하강법 (Gradient Descent)

경사 하강법은 **손실함수(Loss Function)를 최소화하기 위해 모델의 파라미터를 업데이트하는 알고리즘**이다.
# Out:
#   Cell In[14], line 3
#     경사 하강법은 **손실함수(Loss Function)를 최소화하기 위해 모델의 파라미터를 업데이트하는 알고리즘**이다.
#        ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])
w = 0
b = 0
lr = 0.01
epochs = 100
loss_h = []
n = len(x)

# %%
for epoch in range(epochs) :
    y_pred = w * x + b
    
    # 손실 함수
    loss = np.mean((y - y_pred) ** 2)
    loss_h.append(loss)

    # 경사하강법
    dw = (-2/n) * np.sum(x * (y - y_pred))
    db = (-2/n) * np.sum(y - y_pred)

    w = w - lr * dw
    b = b - lr * db

    print(epoch, loss)
# Out:
# 0 17.2
# 1 10.490176
# 2 6.578223155199998
# 3 4.29674325446656
# 4 2.965434332376236
# 5 2.1878500015319484
# 6 1.7329608532076957
# 7 1.4661343051446099
# 8 1.3089130738026944
# 9 1.215576059220508
# 10 1.1594791891009735
# 11 1.1250955389606785
# 12 1.103376708216679
# 13 1.0890496598092771
# 14 1.079041452155182
# 15 1.0715612509126182
# 16 1.0655653708811037
# 17 1.0604455289011807
# 18 1.0558471730745063
# 19 1.051563614023817
# 20 1.0474743298290519
# 21 1.0435090131950633
# 22 1.0396266199175157
# 23 1.0358031593627228
# 24 1.0320245793604372
# 25 1.0282826198683341
# 26 1.0245723966896723
# 27 1.0208909933803376
# 28 1.017236640678749
# 29 1.0136082383150382
# 30 1.01000507634194
# 31 1.006426672737068
# 32 1.0028726787624338
# 33 0.999342823809546
# 34 0.9958368832547737
# 35 0.9923546597239697
# 36 0.9888959721713764
# 37 0.9854606495123166
# 38 0.9820485269096423
# 39 0.9786594436066594
# 40 0.9752932416613062
# 41 0.9719497652055429
# 42 0.9686288600108298
# 43 0.9653303732320069
# 44 0.9620541532551435
# 45 0.9588000496060106
# 46 0.9555679128938855
# 47 0.9523575947759791
# 48 0.9491689479338914
# 49 0.9460018260570994
# 50 0.9428560838305579
# 51 0.9397315769247248
# 52 0.9366281619870047
# 53 0.9335456966340485
# 54 0.9304840394445666
# 55 0.9274430499524579
# 56 0.924422588640142
# 57 0.92142251693203
# 58 0.9184426971880905
# 59 0.9154829926974892
# 60 0.9125432676722957
# 61 0.9096233872412324
# 62 0.9067232174434835
# 63 0.903842625222541
# 64 0.9009814784200977
# 65 0.8981396457699837
# 66 0.8953169968921412
# 67 0.8925134022866423
# 68 0.8897287333277484
# 69 0.8869628622580088
# 70 0.8842156621823989
# 71 0.8814870070624974
# 72 0.8787767717107039
# 73 0.8760848317844994
# 74 0.8734110637807337
# 75 0.8707553450299672
# 76 0.8681175536908381
# 77 0.8654975687444748
# 78 0.8628952699889416
# 79 0.8603105380337268
# 80 0.8577432542942607
# 81 0.8551933009864809
# 82 0.8526605611214247
# 83 0.8501449184998616
# 84 0.8476462577069641
# 85 0.8451644641070114
# 86 0.8426994238381313
# 87 0.840251023807074
# 88 0.8378191516840255
# 89 0.8354036958974536
# 90 0.8330045456289887
# 91 0.8306215908083411
# 92 0.8282547221082467
# 93 0.8259038309394583
# 94 0.8235688094457572
# 95 0.8212495504990078
# 96 0.8189459476942431
# 97 0.8166578953447814
# 98 0.8143852884773773
# 99 0.812128022827409

# %%
plt.plot(loss_h)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
